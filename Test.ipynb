# %%
from binarypipe import imagepipe as ip

# %%
X, y= ip.load_dataset("raw/", 0)
# Out:
# Total 4 image files found
# Processing, Please wait.....Done

# %%
ip.plot(["raw/test1.jpg", 'raw/test6.jpg'])

# %%
XX, yy= ip.load_dataset("raw/", y_element= 0)
ip.plot(XX)
# Out:
# Total 4 image files found
# Processing, Please wait.....Done

# %%
XX.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2b32c0c42303> in <module>
# ----> 1 XX.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
ip.plot("raw/test1.jpg")

# %%
ip.plot(X)

# %%
ip.plot(X[1])

# %%
ip.plot(X[1,:,:,1])

# %%
img= X[0]
ip.show(img)

# %%
imgg= ip.rgb2gray(img)
ip.show(imgg)

# %%
import numpy as np
ip.show(ip.apply_filter(imgg, np.array([[0,0,0],[1,1,1],[-1,-1,-1]])))

# %%
ip.show(ip.apply_filter(imgg, ip.filter.RIGHT_EDGE))

# %%
ip.show(ip.apply_filter(X[3], ip.filter.LEFT_EDGE))

# %%
type('ram')

# %%
K= X[0:3]

# %%
ip.plot(K)

# %%
ip.save(K, "ramji")

# %%
ip.plot(ip.restore("ramji"))
