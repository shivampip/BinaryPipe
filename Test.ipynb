# %%
from binarypipe import imagepipe as ip

# %%
X, y= ip.load_dataset("raw/", 0)
# Out:
# Total 4 image files found
# Resizing DONE
# Converting to Numpy arary DONE

# %%
ip.plot_np_imgs(X)

# %%
ip.show(X[1])

# %%
img= X[0]
ip.show(img)

# %%
imgg= ip.rgb2gray(img)
ip.show(imgg)

# %%
import numpy as np
ip.show(ip.apply_filter(imgg, np.array([[0,0,0],[1,1,1],[-1,-1,-1]])))
